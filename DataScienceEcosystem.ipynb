# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# - short list of popular languages for Data Science
# - list of libraries in Data Science
# - development environment open source tools in Data science
# - basic arithmetic expressoins, such as: addition, multiplication, and division

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. python
# 2. R
# 3. SQL
# 4. C++

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | Data Science Tools|
# |----------|
# |RStudio|
# |Spyder|
# |Jupyter|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author

# %% [markdown]
# Anett Barna
